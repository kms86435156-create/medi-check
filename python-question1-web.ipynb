# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1976D2;background-color:#E3F2FD;padding:5px;font-size:0.9em;">
# 본 자료는 저작권법 제25조 2항에 의해 보호를 받습니다. 본 자료를 외부에 공개하지 말아주세요.<br>
# 본 강의만 잘 정리하면, 데이터 분석, 데이터 과학, 풀스택(백엔드, 프론트엔드) 개발 모두 가능합니다!<br>
# </div>

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1976D2;background-color:#E3F2FD;padding:5px;font-size:0.9em;">
# 제 유투브 채널로 혼자서도 데이터 전과정, 풀스택 전과정을 익힐 수 있는 로드맵과 관련 커리어를  설명한 영상을 만들었는데요<br>
# 꼭 한번 보시면 학습하시는데 큰 그림을 이해하실 수 있으실꺼예요. (괜찮으시면 구독과 좋아요도 부탁드립니다. ㅎ)<br>
# <b>- 데이터, AI 커리어와 데이터 전과정 학습 방법 완벽 가이드: <a href="https://youtu.be/vsoAyh4D-zw">https://youtu.be/vsoAyh4D-zw</a><br>
# - 1인 창업도 가능한 가장 빠른 최신 풀스택 공부순서: <a href="https://youtu.be/mTouChThxzA">https://youtu.be/mTouChThxzA</a></b><br>
# <br>
# 추가로 <strong><a href="https://school.fun-coding.org">잔재미코딩(노이먼스랩)</a></strong> 사이트를 직접 운영중에 있습니다.<br>
# <strong>해당 사이트에서 회원가입하시면, 최신 AI 및 자동화, 데이터, 풀스택 관련 트렌드 뉴스레터도 공유받으실 수 있습니다.</strong>
# </div>

# %% [markdown]
# ## 1. 문제를 풀며 빠르게 익숙해지는 파이썬 기본 프로그래밍1

# %% [markdown]
# ### Exercise 1. 출력
# * 화면에 "Hello World!"를 출력하세요.

# %%
print ("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ### Exercise 2. 출력
# * 화면에 "I don't like C language"를 출력하세요.

# %%
print ("I don't like C language")
# Out:
# I don't like C language

# %% [markdown]
# ### Exercise 3. 출력
# * print 함수를 사용하여 3.1415의 값을 출력하세요.
#   - 단, 소수점 아래는 첫 번째 자리까지만 표시되도록 하세요.
#
# Example <br>
# 3.1

# %%
digit = 3.1415
print ( format(digit, ".1f") )
# Out:
# 3.1

# %% [markdown]
# ### Exercise 4. 형 변환
# * 문자열 '720'를 정수형으로 변환하라. 정수 100을 문자열 '100'으로 변환하라.

# %%
data1 = '720'
print ( int(data1) )

data2 = 100
print ( str(data2) )
# Out:
# 720
# 100

# %% [markdown]
# ### Exercise 5. 연산
# * 2와 4 숫자를 변수에 넣고, 두 변수를 더한 값, 곱한 값, 나눈 값을 출력하세요.
#
# Example <br>
# 6 <br>
# 8 <br>
# 0.5

# %%
num1 = 2
num2 = 4

print (num1 + num2)
print (num1 * num2)
print (num1 / num2)
# Out:
# 6
# 8
# 0.5

# %% [markdown]
# ### Exercise 6. 연산
# * 밑이 6 이고, 지수가 2 일 때 거듭제곱 값을 출력하라.
#   - 6의 2승
#
# Example <br>
# 36

# %%
print ( 6 ** 2 )
# Out:
# 36

# %% [markdown]
# ### Exercise 7.  입력과 출력
# * 사용자로부터 두 개의 숫자를 입력받은 후 두 개의 숫자를 더한 값을 각각 출력하는 프로그램을 작성하세요.
#
# Example<br>
# INPUT: 2 and 4 <br>
# OUTPUT: <br>
#
# 6

# %%
data1 = int(input())
data2 = int(input())

print (data1 + data2)
# Out:
#  2
#  4
# 6

# %% [markdown]
# ### Exercise 8. 입력과 출력
# * 사용자로부터 두 개의 숫자를 입력받은 후 두 개의 숫자를 더한 값, 곱한 값, 나눈 값을 각각 출력하는 프로그램을 작성하세요.
#
# Example<br>
# INPUT: 2 and 4 <br>
# OUTPUT: <br>
#
# 6 <br>
# 8 <br>
# 0.5

# %%
data1 = int(input())
data2 = int(input())

print (data1 + data2)
print (data1 * data2)
print (data1 / data2)
# Out:
#  4
#  8
# 12
# 32
# 0.5

# %% [markdown]
# ### Exercise 9.  입력과 출력
# * 사용자로부터 두 개의 숫자를 입력받은 후 두 개의 숫자를 더한 값, 곱한 값, 나눈 값, 나눈 몫, 나머지 값을 각각 출력하는 프로그램을 작성하세요.
#
# Example<br>
# INPUT: 4 and 4 <br>
# OUTPUT: <br>
#
# 8 <br>
# 16 <br>
# 1.0 <br>
# 1 <br>
# 0

# %%
data1 = int(input())
data2 = int(input())

print (data1 + data2)
print (data1 * data2)
print (data1 / data2)
print (data1 // data2)
print (data1 % data2)
# Out:
#  13
#  5
# 18
# 65
# 2.6
# 2
# 3

# %%
### Exercise 10.  입력과 출력
* 사용자로부터 두 개의 숫자를 입력받은 후 두 개의 숫자를 더한 값, 곱한 값, 나눈 값, 나눈 몫, 나머지 값을 각각 다음과 같이 출력하는 프로그램을 작성하세요.

Example<br>
INPUT: 4 and 4 <br>
OUTPUT: <br>

4 + 4 = 8 <br>
4 * 4 = 16 <br>
4 / 4 = 1 <br>
4 // 4 = 1 <br>
4 % 4 = 0 <br>

# %%
data1 = int(input())
data2 = int(input())

print (data1, "+", data2, "=", data1 + data2)
print (data1, "*", data2, "=", data1 * data2)
print (data1, "/", data2, "=", data1 / data2)
print (data1, "//", data2, "=", data1 // data2)
print (data1, "%", data2, "=", data1 % data2)
# Out:
#  13
#  5
# 13 + 5 = 18
# 13 * 5 = 65
# 13 / 5 = 2.6
# 13 // 5 = 2
# 13 % 5 = 3

# %% [markdown]
# ### Exercise 11.  입력과 출력
# * 사용자로부터 두 개의 숫자를 입력받은 후 두 개의 숫자를 더한 값, 곱한 값, 나눈 값, 나눈 몫, 나머지 값을 각각 다음과 같이 출력하는 프로그램을 작성하세요.
#   - 단, 나눈 값은 소숫점 첫번째 자리까지만 출력하세요.
#
# Example<br>
# INPUT: 5 and 4 <br>
# OUTPUT: <br>
#
# 5 + 4 = 9 <br>
# 5 + 4 = 20 <br>
# 5 / 4 = 1.2 <br>
# 5 // 4 = 1 <br>
# 5 % 4 = 1 <br>

# %%
data1 = int(input())
data2 = int(input())

print (data1, "+", data2, "=", data1 + data2)
print (data1, "*", data2, "=", data1 * data2)
print (data1, "/", data2, "=", format(data1 / data2, ".1f"))
print (data1, "//", data2, "=", data1 // data2)
print (data1, "%", data2, "=", data1 % data2)
# Out:
#  5
#  3
# 5 + 3 = 8
# 5 * 3 = 15
# 5 / 3 = 1.7
# 5 // 3 = 1
# 5 % 3 = 2

# %% [markdown]
# <div class="alert alert-block" style="border: 2px solid #1976D2;background-color:#E3F2FD;padding:5px;font-size:0.9em;">
# 본 자료는 저작권법 제25조 2항에 의해 보호를 받습니다. 본 자료를 외부에 공개하지 말아주세요.<br>
# 본 강의만 잘 정리하면, 데이터 분석, 데이터 과학, 풀스택(백엔드, 프론트엔드) 개발 모두 가능합니다!<br>
# <b><a href="https://school.fun-coding.org/">잔재미코딩</a> 에서 본 강의 기반 최적화된 로드맵도 확인하실 수 있습니다</b></div>
